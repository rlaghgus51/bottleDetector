# %%
# %cd /content/drive/MyDrive
# !pwd
# Out:
# /content/drive/MyDrive
# /content/drive/MyDrive

# %%
# %cd /content/drive/MyDrive/
# !git clone https://github.com/rlaghgus51/cokeDetector
# !ls | grep coke
# %cd cokeDetector/
# !pwd
# Out:
# /content/drive/MyDrive
# Cloning into 'cokeDetector'...
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 8 (delta 1), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (8/8), done.
# cokeDetector
# cokeDetectorBackup
# cokeDetectorBackup2
# cokeDetectorBackup3
# /content/drive/MyDrive/cokeDetector
# /content/drive/MyDrive/cokeDetector

# %%
# %cd /content/drive/MyDrive/cokeDetector
# !ls -slah
# Out:
# /content/drive/MyDrive/cokeDetector
# total 8.0K
# 4.0K drwx------ 8 root root 4.0K Dec 21 13:45 .git
# 2.0K -rw------- 1 root root 1.8K Dec 21 13:45 .gitignore
# 1.5K -rw------- 1 root root 1.1K Dec 21 13:45 LICENSE
#  512 -rw------- 1 root root   31 Dec 21 13:45 README.md

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/cokeDetector/.git/

# %%
# %cd /content/drive/MyDrive/
# !cp ./cokeDetectorBackup2/data/*.JPG ./cokeDetector/data
# !cp ./cokeDetectorBackup3/yolo_v4_test_train_Roboflow_ok.ipynb ./cokeDetector/
# !cp ./cokeDetectorBackup3/cokeDetector.ipynb ./cokeDetector/data
# !cp ./cokeDetectorBackup3/data/*.JPG ./cokeDetector/data
# Out:
# /content/drive/MyDrive

# %%
# git pull & push 하기
# 50mb 이내 data
# !git add .
# !git commit -m "first commit"

# !git config --global user.email "rlaghgus51@gmail.com"
# !git config --global user.name "rlaghgus51"
# Out:
# [main 3058adc] first commit
#  22 files changed, 2 insertions(+)
#  create mode 100644 cokeDetector.ipynb
#  create mode 100644 data/IMG_2380.JPG
#  create mode 100644 data/IMG_2381.JPG
#  create mode 100644 data/IMG_2382.JPG
#  create mode 100644 data/IMG_2383.JPG
#  create mode 100644 data/IMG_2384.JPG
#  create mode 100644 data/IMG_2385.JPG
#  create mode 100644 data/IMG_2386.JPG
#  create mode 100644 data/IMG_2387.JPG
#  create mode 100644 data/IMG_2388.JPG
#  create mode 100644 data/IMG_2389.JPG
#  create mode 100644 data/IMG_2390.JPG
#  create mode 100644 data/IMG_2391.JPG
#  create mode 100644 data/IMG_2392.JPG
#  create mode 100644 data/IMG_2393.JPG
#  create mode 100644 data/IMG_2394.JPG
#  create mode 100644 data/IMG_2395.JPG
#  create mode 100644 data/IMG_2396.JPG
#  create mode 100644 data/IMG_2397.JPG
#  create mode 100644 data/IMG_2398.JPG
#  create mode 100644 data/IMG_2399.JPG
#  create mode 100644 yolo_v4_test_train_Roboflow_ok.ipynb
# ...

# %%
# !git remote add origin "github.com/rlaghgus51/cokeDetector"
# !git push -u origin master
# Out:
# fatal: remote origin already exists.
# error: src refspec master does not match any.
# error: failed to push some refs to 'https://github.com/rlaghgus51/cokeDetector'

# %%
# !git add .
# !git commit -m "first commit"

# !git push origin master
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 2 commits.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean
# error: src refspec master does not match any.
# error: failed to push some refs to 'https://github.com/rlaghgus51/cokeDetector'

# %%
# !git remote add origin https://github.com/rlaghgus51/cokeDetector
# !git push origin master
# Out:
# fatal: remote origin already exists.
# error: src refspec master does not match any.
# error: failed to push some refs to 'https://github.com/rlaghgus51/cokeDetector'

# %%
# !git remote
# Out:
# origin

# %%
# %cd /content/drive/MyDrive/
# !git pull
# Out:
# /content/drive/MyDrive
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
